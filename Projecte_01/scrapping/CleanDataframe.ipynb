# %%
import pandas as pd
# from pandas import json_normalize

df = pd.read_json('../res/mobiles.json')
# df = json_normalize(df.to_dict(orient='records'), sep='_')
# df.columns = [col.replace('detalles_tecnicos_', '') for col in df.columns]
df.set_index('product_id', inplace=True)
df
# Out:
#            precio_actual precio_anterior            OS    RAM  \
# product_id
# B0CCW32ZH2      230,.00           399,00  Android 13.0  12 GB
# B0DRD2J39F      159,.34           167,37           NaN    NaN
# B0D2L42BX9      378,.90           549,99       Android   8 GB
# B0DKT15QW9       99,.99             None           NaN    NaN
# B0D5DF24YP      292,.19           499,99       Android    NaN
# ...                  ...             ...           ...    ...
# B0CR17BMLT      298,.23           419,90  Android 13.0  12 GB
# B0D2QFYJTQ      229,.00           499,99           NaN    NaN
# B0DNYQMD8X      126,.49           131,57           NaN    NaN
# B0D1FQ4J92      149,.99           499,99           NaN    NaN
# B08VW9J5GV       79,.99           209,99           NaN    NaN
#
#            Peso del producto       Dimensiones del producto  \
# product_id
# B0CCW32ZH2             170 g       16 x 0,8 x 7,2 cm; 170 g
# B0DRD2J39F             200 g  0,82 x 7,66 x 16,33 cm; 200 g
# B0D2L42BX9             410 g                            NaN
# B0DKT15QW9             199 g  16,68 x 7,75 x 0,87 cm; 199 g
# B0D5DF24YP             178 g  16,14 x 7,41 x 0,75 cm; 178 g
# ...                      ...                            ...
# B0CR17BMLT             500 g   16,05 x 7,5 x 0,85 cm; 500 g
# B0D2QFYJTQ             191 g  16,32 x 7,58 x 0,78 cm; 191 g
# B0DNYQMD8X             380 g                            NaN
# B0D1FQ4J92             208 g                            NaN
# B08VW9J5GV             189 g   16,7 x 7,74 x 0,89 cm; 189 g
#
#                                                     Pilas  \
# product_id
# B0CCW32ZH2  1 Polimero de litio necesaria(s), incluida(s)
# B0DRD2J39F   1 Polimero de litio (Tipo de pila necesaria)
# B0D2L42BX9          1 Litio Ion necesaria(s), incluida(s)
# B0DKT15QW9               1 12 V necesaria(s), incluida(s)
# B0D5DF24YP          1 Litio Ion necesaria(s), incluida(s)
# ...                                                   ...
# B0CR17BMLT                   1 A (Tipo de pila necesaria)
# B0D2QFYJTQ          1 Litio Ion necesaria(s), incluida(s)
# B0DNYQMD8X                1 CR5 necesaria(s), incluida(s)
# B0D1FQ4J92  1 Polimero de litio necesaria(s), incluida(s)
# B08VW9J5GV                                            NaN
#
#             Numero de modelo del producto  \
# product_id
# B0CCW32ZH2                     PAYH0034SE
# B0DRD2J39F                  Redmi Note 14
# B0D2L42BX9                        RMX3853
# B0DKT15QW9         OUKITEL C58 Smartphone
# B0D5DF24YP                  631001003106B
# ...                                   ...
# B0CR17BMLT                     2311DRK48G
# B0D2QFYJTQ  vivo V40 SE 5G Leather Purple
# B0DNYQMD8X                            NaN
# B0D1FQ4J92              Blackview N6000SE
# B08VW9J5GV                            NaN
#
#            Tecnologia de comunicacion inalambrica Tecnologia de conectividad  \
# product_id
# B0CCW32ZH2                                     5G       Bluetooth, USB, Wifi
# B0DRD2J39F                                    NaN                        NaN
# B0D2L42BX9                           Celular, NFC                        NaN
# B0DKT15QW9                                    NaN                        NaN
# B0D5DF24YP                                Celular                         5G
# ...                                           ...                        ...
# B0CR17BMLT                                     5G                        NFC
# B0D2QFYJTQ                                    NaN                        NaN
# B0DNYQMD8X                                    NaN                        NaN
# B0D1FQ4J92                                    NaN                        NaN
# B08VW9J5GV                                    NaN                        NaN
#
#             ... Proveedor de conexion inalambrica  \
# product_id  ...
# B0CCW32ZH2  ...                               NaN
# B0DRD2J39F  ...                               NaN
# B0D2L42BX9  ...                               NaN
# B0DKT15QW9  ...                               NaN
# B0D5DF24YP  ...                               NaN
# ...         ...                               ...
# B0CR17BMLT  ...                               NaN
# B0D2QFYJTQ  ...                               NaN
# B0DNYQMD8X  ...                               NaN
# B0D1FQ4J92  ...                               NaN
# B08VW9J5GV  ...                               NaN
#
#            Duracion de la bateria media (en horas) Pilas incluidas  \
# product_id
# B0CCW32ZH2                                     NaN             NaN
# B0DRD2J39F                                     NaN             NaN
# B0D2L42BX9                                     NaN             NaN
# B0DKT15QW9                                     NaN             NaN
# B0D5DF24YP                                     NaN             NaN
# ...                                            ...             ...
# B0CR17BMLT                                     NaN             NaN
# B0D2QFYJTQ                                     NaN             NaN
# B0DNYQMD8X                                     NaN             NaN
# B0D1FQ4J92                                     NaN             NaN
# B08VW9J5GV                                     NaN             NaN
#
#            Contenido de energia de la bateria de litio  \
# product_id
# B0CCW32ZH2                                         NaN
# B0DRD2J39F                                         NaN
# B0D2L42BX9                                         NaN
# B0DKT15QW9                                         NaN
# B0D5DF24YP                                         NaN
# ...                                                ...
# B0CR17BMLT                                         NaN
# B0D2QFYJTQ                                         NaN
# B0DNYQMD8X                                         NaN
# B0D1FQ4J92                                         NaN
# B08VW9J5GV                                         NaN
#
#            Embalaje de la bateria de litio Numero de pilas de ion de litio  \
# product_id
# B0CCW32ZH2                             NaN                             NaN
# B0DRD2J39F                             NaN                             NaN
# B0D2L42BX9                             NaN                             NaN
# B0DKT15QW9                             NaN                             NaN
# B0D5DF24YP                             NaN                             NaN
# ...                                    ...                             ...
# B0CR17BMLT                             NaN                             NaN
# B0D2QFYJTQ                             NaN                             NaN
# B0DNYQMD8X                             NaN                             NaN
# B0D1FQ4J92                             NaN                             NaN
# B08VW9J5GV                             NaN                             NaN
#
#            Numero de pilas de metal de litio Tipo de conectividad  \
# product_id
# B0CCW32ZH2                               NaN                  NaN
# B0DRD2J39F                               NaN                  NaN
# B0D2L42BX9                               NaN                  NaN
# B0DKT15QW9                               NaN                  NaN
# B0D5DF24YP                               NaN                  NaN
# ...                                      ...                  ...
# B0CR17BMLT                               NaN                  NaN
# B0D2QFYJTQ                               NaN                  NaN
# B0DNYQMD8X                               NaN                  NaN
# B0D1FQ4J92                               NaN                  NaN
# B08VW9J5GV                               NaN                  NaN
#
#            Resolucion de la camara web frontal  \
# product_id
# B0CCW32ZH2                                 NaN
# B0DRD2J39F                                 NaN
# B0D2L42BX9                                 NaN
# B0DKT15QW9                                 NaN
# B0D5DF24YP                                 NaN
# ...                                        ...
# B0CR17BMLT                                 NaN
# B0D2QFYJTQ                                 NaN
# B0DNYQMD8X                                 NaN
# B0D1FQ4J92                                 NaN
# B08VW9J5GV                                 NaN
#
#            Tiempo de carga de la bateria (en horas)
# product_id
# B0CCW32ZH2                                      NaN
# B0DRD2J39F                                      NaN
# B0D2L42BX9                                      NaN
# B0DKT15QW9                                      NaN
# B0D5DF24YP                                      NaN
# ...                                             ...
# B0CR17BMLT                                      NaN
# B0D2QFYJTQ                                      NaN
# B0DNYQMD8X                                      NaN
# B0D1FQ4J92                                      NaN
# B08VW9J5GV                                      NaN
#
# [244 rows x 117 columns]

# %% [markdown]
# ## Eliminamos las columnas que no aportan valor

# %%
columnas_excluidas = {
    "Numero de pilas de ion de litio", "Que hay en la caja?","Formatos de audio compatibles","Otras caracteristicas","Otras caracteristicas","Adaptador","Formatos compatibles", "Tiene estabilizador de imagen", 
    "Tipo de medio", "Aparatos compatibles","Descripcion de la interfaz de red","Caracteristicas especiales","Resolucion horizontal", "Tecnologia del microfono", "Resolucion vertical max.", 
    "Tecnologia de comunicacion inalámbrica","Grabador","Formatos de audio compatibles","Series","Carga electrica de la bateria","OS","Tiempo de carga","Conector de audio","Resolucion de la camara web trasera","Maxima resolucion","Pilas incluidas","Software incluido","Tamano","Tipo de conector","Ranuras de memoria disponibles","Composicion de la pila de la bateria","Fuente de alimentacion"," Proveedor de conexion inalambrica","Velocidad de transferencia de datos", "Descripcion de la bateria", "Duracion de la bateria media (en horas)", 
    "Marca de la tarjeta grafica","Zoom digital","Enfoque automatico","Tiempo de carga de la bateria (en horas)","Memoria extraible","Proveedor de conexion inalambrica","Tamano de la tarjeta de memoria incluida","Relacion de aspecto de imagen", "Dimensiones del paquete", "Embalaje de la bateria de litio", "Tipo de dispositivo", 
    "Actualizaciones de software garantizadas hasta", "Tecnologia de comunicacion inalambrica","Compilador", "Numero de pilas de metal de litio", "Voltaje", 
    "Resolucion de pantalla","Tiempo de conversacion telefonica", "Numero de puertos USB", "Contenido de energia de la bateria de litio", "Lector", 
    "Marimba", "Tipo de material", "Incluye bateria recargable", "Tiene vision nocturna", "Pantalla a color", 
    "Proveedor de conexion inalámbrica", "Tipo de lente","Descripcion de la tarjeta grafica", "GPS", "Otras caracteristicas de la pantalla", 
    "Tipo de conexion inalámbrica", "Numero de puertos", "Pilas", "Numero de modelo del producto", "Tecnologia de conectividad", "Entrada de interfaz humana", "Otras funciones de la camara", "Color", "Compatible con tecnologia Bluetooth", "0",
    "Referencia del fabricante", "Tipo de conexion inalambrica", "Tamano de pantalla", "Pilas / baterias incluida", "Pilas / baterias necesarias",
    'Peso del producto',
    'Resolucion del escaner',
    'Numero de producto',
    'Componentes incluidos',
    'Numero de productos',
    'Resolucion del sensor optico',
    'Tecnologia GSM',
    'Factor de forma',
    'Resolucion maxima',
    'Peso de la bateria de litio',
    'Hora de espera del telefono (con datos)',
    'Tecnologia del sintonizador',
    'Contiene liquidos',
    'Duracion media de la pila en stand-by',
    'Transcriptor',
    "Modelo",
    'Duracion media de la bateria',
    'Pilas / baterias incluidas', 'Tipo de memoria del ordenador', 'Coprocesador grafico', 'Nombre del modelo', 'Capacidad de la memoria flash instalada',
    'Material'
    

}

df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

df.head()
# Out:
#            precio_actual precio_anterior    RAM  \
# product_id
# B0CCW32ZH2      230,.00           399,00  12 GB
# B0DRD2J39F      159,.34           167,37    NaN
# B0D2L42BX9      378,.90           549,99   8 GB
# B0DKT15QW9       99,.99             None    NaN
# B0D5DF24YP      292,.19           499,99    NaN
#
#                  Dimensiones del producto Tecnologia de pantalla  \
# product_id
# B0CCW32ZH2       16 x 0,8 x 7,2 cm; 170 g                   OLED
# B0DRD2J39F  0,82 x 7,66 x 16,33 cm; 200 g                    NaN
# B0D2L42BX9                            NaN                    NaN
# B0DKT15QW9  16,68 x 7,75 x 0,87 cm; 199 g                    NaN
# B0D5DF24YP  16,14 x 7,41 x 0,75 cm; 178 g                 AMOLED
#
#            Potencia nominal de la bateria    Marca Fabricante  \
# product_id
# B0CCW32ZH2   5000 Modificador desconocido      NaN        NaN
# B0DRD2J39F                           5500   Xiaomi     Xiaomi
# B0D2L42BX9   5500 Modificador desconocido      NaN        NaN
# B0DKT15QW9   5150 Miliamperios hora (mAh)  OUKITEL    OUKITEL
# B0D5DF24YP              3600 Amperio-hora      NaN        NaN
#
#            Capacidad de la memoria Capacidad de la memoria RAM instalada  ...  \
# product_id                                                                ...
# B0CCW32ZH2                     NaN                                   NaN  ...
# B0DRD2J39F                  128 GB                                  6 GB  ...
# B0D2L42BX9                     NaN                                   NaN  ...
# B0DKT15QW9                  128 GB                                 16 GB  ...
# B0D5DF24YP                     NaN                                   NaN  ...
#
#            Relacion de aspecto Capacidad de la memoria RAM  \
# product_id
# B0CCW32ZH2                 NaN                         NaN
# B0DRD2J39F                 NaN                         NaN
# B0D2L42BX9                 NaN                         NaN
# B0DKT15QW9                 NaN                         NaN
# B0D5DF24YP                 NaN                         NaN
#
#            Soporta bandas de radio Numero de procesadores  \
# product_id
# B0CCW32ZH2                     NaN                    NaN
# B0DRD2J39F                     NaN                    NaN
# B0D2L42BX9                     NaN                    NaN
# B0DKT15QW9                     NaN                    NaN
# B0D5DF24YP                     NaN                    NaN
#
#            Resolucion vertical max Interfaz del hardware  Numero de modelo  \
# product_id
# B0CCW32ZH2                     NaN                   NaN               NaN
# B0DRD2J39F                     NaN                   NaN               NaN
# B0D2L42BX9                     NaN                   NaN               NaN
# B0DKT15QW9                     NaN                   NaN               NaN
# B0D5DF24YP                     NaN                   NaN               NaN
#
#            Capacidad de grabacion Tipo de conectividad  \
# product_id
# B0CCW32ZH2                    NaN                  NaN
# B0DRD2J39F                    NaN                  NaN
# B0D2L42BX9                    NaN                  NaN
# B0DKT15QW9                    NaN                  NaN
# B0D5DF24YP                    NaN                  NaN
#
#            Resolucion de la camara web frontal
# product_id
# B0CCW32ZH2                                 NaN
# B0DRD2J39F                                 NaN
# B0D2L42BX9                                 NaN
# B0DKT15QW9                                 NaN
# B0D5DF24YP                                 NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Problemes per solucionar en este codic, si la columna no existeix peta si ja hi ha una columna amb el nom del nom objectiu dins de el diccionari dins de la llista objectiu peta

# %% [markdown]
# ## Unimos columnas similares

# %%
fusion_columnas = {
    "Memoria RAM": ["RAM", "Capacidad de la memoria RAM", "Capacidad de la memoria RAM instalada", "Memoria RAM", "Capacidad de la memoria"],
    "Marca": ["Marca", "Fabricante"],
    "Tipo de pantalla": ["Tipo de pantalla", "Tecnologia de pantalla"]
}

for col_final, columnas_equivalentes in fusion_columnas.items():
    columnas_presentes = [col for col in columnas_equivalentes if col in df.columns]

    if columnas_presentes:
        nueva_columna = []
        for index, row in df.iterrows():
            encontrado = False
            for col in columnas_presentes:
                if pd.notna(row[col]):
                    nueva_columna.append(row[col])
                    encontrado = True
                    break
            if not encontrado:
                nueva_columna.append(None) 

        df[col_final] = nueva_columna

        for col in columnas_presentes:
            if col != col_final:
                df.drop(columns=col, inplace=True)

# %%
df.columns
# Out:
# Index(['precio_actual', 'precio_anterior', 'Dimensiones del producto',
#        'Potencia nominal de la bateria', 'Marca',
#        'Capacidad de almacenamiento digital', 'Sistema operativo',
#        'Fabricante del procesador', 'Tipo de procesador',
#        'Tamano de la pantalla', 'Tipo de pantalla', 'Ano del modelo',
#        'Velocidad del procesador', 'Resolucion efectiva de video',
#        'Resolucion de captura de video', 'Frecuencia de actualizacion',
#        'Relacion de aspecto', 'Soporta bandas de radio',
#        'Numero de procesadores', 'Resolucion vertical max',
#        'Interfaz del hardware', 'Numero de modelo', 'Capacidad de grabacion',
#        'Tipo de conectividad', 'Resolucion de la camara web frontal',
#        'Memoria RAM'],
#       dtype='object')

# %% [markdown]
# ## Filtramos columnas

# %% [markdown]
# Eliminamos las culomnas que tienen un porcentaje de nulos mayor al indicado

# %%
threshold = 0.40 * len(df)
df = df.dropna(axis=1, thresh=threshold)
df
# Out:
#            precio_actual precio_anterior       Dimensiones del producto  \
# product_id
# B0CCW32ZH2      230,.00           399,00       16 x 0,8 x 7,2 cm; 170 g
# B0DRD2J39F      159,.34           167,37  0,82 x 7,66 x 16,33 cm; 200 g
# B0D2L42BX9      378,.90           549,99                            NaN
# B0DKT15QW9       99,.99             None  16,68 x 7,75 x 0,87 cm; 199 g
# B0D5DF24YP      292,.19           499,99  16,14 x 7,41 x 0,75 cm; 178 g
# ...                  ...             ...                            ...
# B0CR17BMLT      298,.23           419,90   16,05 x 7,5 x 0,85 cm; 500 g
# B0D2QFYJTQ      229,.00           499,99  16,32 x 7,58 x 0,78 cm; 191 g
# B0DNYQMD8X      126,.49           131,57                            NaN
# B0D1FQ4J92      149,.99           499,99                            NaN
# B08VW9J5GV       79,.99           209,99   16,7 x 7,74 x 0,89 cm; 189 g
#
#            Potencia nominal de la bateria      Marca  \
# product_id
# B0CCW32ZH2   5000 Modificador desconocido       None
# B0DRD2J39F                           5500     Xiaomi
# B0D2L42BX9   5500 Modificador desconocido       None
# B0DKT15QW9   5150 Miliamperios hora (mAh)    OUKITEL
# B0D5DF24YP              3600 Amperio-hora       None
# ...                                   ...        ...
# B0CR17BMLT                           5000       None
# B0D2QFYJTQ                           5000       VIVO
# B0DNYQMD8X                           5160     Xiaomi
# B0D1FQ4J92   3700 Miliamperios hora (mAh)  Blackview
# B08VW9J5GV                           4350     DOOGEE
#
#            Capacidad de almacenamiento digital      Sistema operativo  \
# product_id
# B0CCW32ZH2                                 NaN                    NaN
# B0DRD2J39F                                6 GB           Android 12.0
# B0D2L42BX9                                 NaN                    NaN
# B0DKT15QW9                               16 GB  Android 14 Smartphone
# B0D5DF24YP                                 NaN                    NaN
# ...                                        ...                    ...
# B0CR17BMLT                                 NaN                    NaN
# B0D2QFYJTQ                              256 GB             Android 14
# B0DNYQMD8X                              128 GB               Androide
# B0D1FQ4J92                                4 GB           Android 13.0
# B08VW9J5GV                               32 GB           Android 10.0
#
#            Tamano de la pantalla Tipo de pantalla  Ano del modelo Memoria RAM
# product_id
# B0CCW32ZH2                   NaN             OLED             NaN       12 GB
# B0DRD2J39F     16,94 Centimetros           AMOLED             NaN        6 GB
# B0D2L42BX9                   NaN             None             NaN        8 GB
# B0DKT15QW9         6,67 Pulgadas              LCD          2025.0       16 GB
# B0D5DF24YP                   NaN           AMOLED             NaN        None
# ...                          ...              ...             ...         ...
# B0CR17BMLT                   NaN           AMOLED             NaN       12 GB
# B0D2QFYJTQ         6,67 Pulgadas           AMOLED          2024.0        8 GB
# B0DNYQMD8X         6,88 Pulgadas              LCD          2024.0      256 GB
# B0D1FQ4J92          4,3 Pulgadas              LCD          2024.0       12 GB
# B08VW9J5GV         6,52 Pulgadas             None             NaN        4 GB
#
# [244 rows x 11 columns]

# %% [markdown]
# ## Mapeo de columnas

# %%
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df['precio_actual'] = df['precio_actual'].replace({',': '', '\\.': ''}, regex=True)
df['precio_actual'] = df['precio_actual'].replace({'\\.': ''}, regex=True)
df['precio_actual'] = df['precio_actual'].astype(float)/100

df['precio_anterior'] = df['precio_anterior'].replace({',': '', '\\.': ''}, regex=True)
df['precio_anterior'] = df['precio_anterior'].astype(float)/100


df['Potencia nominal de la bateria'] = df['Potencia nominal de la bateria'].str.extract(r'(\d+)').astype(float)
df['Capacidad de almacenamiento digital'] = df['Capacidad de almacenamiento digital'].str.extract(r'(\d+)').astype(float)
df['Memoria RAM'] = df['Memoria RAM'].str.extract(r'(\d+)').astype(float)
# Out:
# /tmp/ipykernel_16824/2269640380.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
def convertir_tamaño(valor):
    if isinstance(valor, str):
        if 'centimetros' in valor:
            numero = float(valor.split(' ')[0].replace(',', '.'))
            return round(numero / 2.54, 2)
        elif 'pulgadas' in valor:
            numero = float(valor.split(' ')[0].replace(',', '.'))
            return round(numero, 2)
    elif isinstance(valor, (int, float)):
        return round(valor, 2)
    return None

df['Tamano de la pantalla'] = df['Tamano de la pantalla'].apply(convertir_tamaño)

# %%
def estandarizar_pantalla(valor):
    if isinstance(valor, str):  # Verificar si el valor es una cadena de texto
        if 'super amoled' in valor or 'superamoled' in valor:
            return 'superamoled'
        elif 'amoled' in valor:
            return 'amoled'
        elif 'oled' in valor:
            return 'oled'
        elif 'lcd' in valor:
            return 'lcd'
    return valor  # En caso de que no sea una cadena, retornar el valor original

# Aplicar la función a la columna
df['Tipo de pantalla'] = df['Tipo de pantalla'].apply(estandarizar_pantalla)

# %%
df.to_csv("temp.csv")
df
# Out:
#             precio_actual  precio_anterior       Dimensiones del producto  \
# product_id
# B0CCW32ZH2         230.00           399.00       16 x 0,8 x 7,2 cm; 170 g
# B0DRD2J39F         159.34           167.37  0,82 x 7,66 x 16,33 cm; 200 g
# B0D2L42BX9         378.90           549.99                            NaN
# B0DKT15QW9          99.99              NaN  16,68 x 7,75 x 0,87 cm; 199 g
# B0D5DF24YP         292.19           499.99  16,14 x 7,41 x 0,75 cm; 178 g
# ...                   ...              ...                            ...
# B0CR17BMLT         298.23           419.90   16,05 x 7,5 x 0,85 cm; 500 g
# B0D2QFYJTQ         229.00           499.99  16,32 x 7,58 x 0,78 cm; 191 g
# B0DNYQMD8X         126.49           131.57                            NaN
# B0D1FQ4J92         149.99           499.99                            NaN
# B08VW9J5GV          79.99           209.99   16,7 x 7,74 x 0,89 cm; 189 g
#
#             Potencia nominal de la bateria      Marca  \
# product_id
# B0CCW32ZH2                          5000.0       None
# B0DRD2J39F                          5500.0     xiaomi
# B0D2L42BX9                          5500.0       None
# B0DKT15QW9                          5150.0    oukitel
# B0D5DF24YP                          3600.0       None
# ...                                    ...        ...
# B0CR17BMLT                          5000.0       None
# B0D2QFYJTQ                          5000.0       vivo
# B0DNYQMD8X                          5160.0     xiaomi
# B0D1FQ4J92                          3700.0  blackview
# B08VW9J5GV                          4350.0     doogee
#
#             Capacidad de almacenamiento digital      Sistema operativo  \
# product_id
# B0CCW32ZH2                                  NaN                    NaN
# B0DRD2J39F                                  6.0           android 12.0
# B0D2L42BX9                                  NaN                    NaN
# B0DKT15QW9                                 16.0  android 14 smartphone
# B0D5DF24YP                                  NaN                    NaN
# ...                                         ...                    ...
# B0CR17BMLT                                  NaN                    NaN
# B0D2QFYJTQ                                256.0             android 14
# B0DNYQMD8X                                128.0               androide
# B0D1FQ4J92                                  4.0           android 13.0
# B08VW9J5GV                                 32.0           android 10.0
#
#             Tamano de la pantalla Tipo de pantalla  Ano del modelo  \
# product_id
# B0CCW32ZH2                    NaN             oled             NaN
# B0DRD2J39F                   6.67           amoled             NaN
# B0D2L42BX9                    NaN             None             NaN
# B0DKT15QW9                   6.67              lcd          2025.0
# B0D5DF24YP                    NaN           amoled             NaN
# ...                           ...              ...             ...
# B0CR17BMLT                    NaN           amoled             NaN
# B0D2QFYJTQ                   6.67           amoled          2024.0
# B0DNYQMD8X                   6.88              lcd          2024.0
# B0D1FQ4J92                   4.30              lcd          2024.0
# B08VW9J5GV                   6.52             None             NaN
#
#             Memoria RAM
# product_id
# B0CCW32ZH2         12.0
# B0DRD2J39F          6.0
# B0D2L42BX9          8.0
# B0DKT15QW9         16.0
# B0D5DF24YP          NaN
# ...                 ...
# B0CR17BMLT         12.0
# B0D2QFYJTQ          8.0
# B0DNYQMD8X        256.0
# B0D1FQ4J92         12.0
# B08VW9J5GV          4.0
#
# [244 rows x 11 columns]

# %% [markdown]
# ## Gestion de nulos

# %%
columnas = ["Memoria RAM","Dimensiones del producto", "Capacidad de la memoria","Tamano de la pantalla", "Tipo de pantalla"]
for col in columnas:
    moda = df[col].mode(dropna=True)
    if not moda.empty:
        df[col] = df[col].fillna(moda[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PIA_Projectes/Projecte_01/projecte01_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Capacidad de la memoria'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[331], line 3
#       1 columnas = ["Memoria RAM","Dimensiones del producto", "Capacidad de la memoria","Tamano de la pantalla", "Tipo de pantalla"]
#       2 for col in columnas:
# ----> 3     moda = df[col].mode(dropna=True)
#       4     if not moda.empty:
#       5         df[col] = df[col].fillna(moda[0])
#
# File ~/PIA_Projectes/Projecte_01/projecte01_venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/PIA_Projectes/Projecte_01/projecte01_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Capacidad de la memoria'

# %%
df.isnull().sum()
# Out:
# precio_actual                       0
# precio_anterior                     0
# Marca                             212
# Sistema operativo                 218
# Tamano de la pantalla             218
# Tipo de pantalla                  155
# Potencia nominal de la bateria    107
# Dimensiones del producto          212
# Memoria RAM                       142
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, B0CCW32ZH2 to B08VW9J5GV
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   precio_actual                        244 non-null    float64
#  1   precio_anterior                      216 non-null    float64
#  2   Dimensiones del producto             244 non-null    object
#  3   Potencia nominal de la bateria       223 non-null    float64
#  4   Marca                                137 non-null    object
#  5   Capacidad de almacenamiento digital  118 non-null    float64
#  6   Sistema operativo                    134 non-null    object
#  7   Tamano de la pantalla                130 non-null    float64
#  8   Tipo de pantalla                     177 non-null    object
#  9   Ano del modelo                       118 non-null    float64
#  10  Memoria RAM                          244 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 22.9+ KB

# %%
df.to_csv("temp.csv")

# %% [markdown]
# ## TODO:
# - GEstionar columna capacidad de memoria
# - Deteccion de outliders
